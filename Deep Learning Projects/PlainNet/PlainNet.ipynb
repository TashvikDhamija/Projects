# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import pandas as pd
import numpy as np

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as T
import PIL

from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **DATA TRANSFORM**

# %%
transform = T.Compose(
                [T.ToTensor(),T.Normalize((0.5,),(0.5,))]
                     )

# %% [markdown]
# **LOADING CIFAR10 DATASET**

# %%
import torchvision.datasets as dset
from torch.utils.data import sampler,DataLoader

class ChunkSampler(sampler.Sampler):
    """Samples elements sequentially from some offset. 
    Arguments:
        num_samples: # of desired datapoints
        start: offset where we should start selecting from
    """
    def __init__(self, num_samples, start = 0):
        self.num_samples = num_samples
        self.start = start

    def __iter__(self):
        return iter(range(self.start, self.start + self.num_samples))

    def __len__(self):
        return self.num_samples


NUM_TRAIN = 49000
NUM_VAL = 1000

trainSet = dset.CIFAR10(root = 'OneDrive/Documents/Machine Learning/DL/', 
                             train=True, 
                             download=True,
                             transform=transform)

trainLoader = DataLoader(trainSet, 
                          batch_size=128, 
                          sampler=ChunkSampler(NUM_TRAIN, 0))

valSet = dset.CIFAR10(root = 'OneDrive/Documents/Machine Learning/DL/', 
                           train=True, 
                           download=True,
                           transform=transform)

valLoader = DataLoader(valSet, 
                        batch_size=128, 
                        sampler=ChunkSampler(NUM_VAL, NUM_TRAIN))

testSet = dset.CIFAR10(root = 'OneDrive/Documents/Machine Learning/DL/', 
                            train=False, 
                            download=True,
                            transform=transform)

testLoader = DataLoader(testSet, 
                         batch_size=128)
classes = ('plane', 'car', 'bird', 'cat', 'deer', 
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# **VISUALIZING DATA**

# %%
fig = plt.figure(figsize = (12,12))
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.imshow(trainSet.data[i])

# %%
print(trainSet.data.shape)
print(testSet.data.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# **TRAINING and ACCURACY FUNCTIONS**

# %%
def train(net,loss_func,opt,num_epoch=1):
    iteration = 0
    loss_list = []
    iter_list = []
    val_acc_list = []
    for epoch in range(num_epoch):
        print("Epoch %d/%d"%(epoch+1,num_epoch))
        net.train()
        for i,data in enumerate(trainLoader,0):
            torch.cuda.empty_cache()
            inputs, labels = data

            # Using GPU
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Wrapping in Variable
            inputs, labels = Variable(inputs), Variable(labels)

            # Clearing previous gradients
            opt.zero_grad()

            # Forward Propagation
            scores = net(inputs)
            loss = loss_func(scores,labels)

            # Backpropagation
            loss.backward()
            opt.step()

            iteration += 1
            if iteration % 50 == 0:
                loss_list.append(loss)
                iter_list.append(iteration)
                # Print Loss
                print('Iteration: %d, loss = %0.2f'%(iteration,loss))
        
        val_acc = check_accuracy(net,valLoader)
        val_acc_list.append(val_acc)
        
    
    return iter_list,loss_list,val_acc_list

# %%
def vizualize(iter_l,loss_l,val_l,epochs=1):
    # visualizing loss function
    plt.plot(iter_l,loss_l)
    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.title('Optimizing Lost function over CIFAR10 Dataset')
    plt.show()

    #visualizing Val Accuracy
    plt.plot(np.arange(epochs),val_l)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Accuracy over Validation Set')
    plt.show()

# %%
def check_accuracy(model,loader):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')
    num_correct = 0
    num_samples = 0
    model.eval()
    for i,data in enumerate(loader,0):
            torch.cuda.empty_cache()
            inputs, labels = data
            
            # Using GPU
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Forward Propagation
            scores = net(inputs)
            # Get predictions from the maximum value
            predicted = torch.max(scores.data, 1)[1]
                
            # Total number of labels
            num_samples += len(labels)
                
            num_correct += (predicted == labels).sum()
            
    accuracy = 100 * num_correct / float(num_samples)
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, accuracy))
    return accuracy

# %% [markdown]
# **CNN MODEL FOR CIFAR10**

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        
        # Defining CNN
        # Conv Architecture:
        '''
        conv2d->ReLU->conv2d->ReLU->BatchNorm->maxpool2d(32x32=>16x16)->
        conv2d->ReLU->conv2d->ReLU->BatchNorm->maxpool2d(16x16=>8x8)->Dropout->
        conv2d->ReLU->conv2d->ReLU->BatchNorm->axpool2d(8x8=>4X4)->
        Classifier
        '''
        self.cnn = nn.Sequential(nn.Conv2d(3,32,3,1,1),
                                 nn.ReLU(inplace = True),
                                 nn.BatchNorm2d(32),
                                 nn.Conv2d(32,64,3,1,1),
                                 nn.ReLU(inplace = True),
                                 nn.BatchNorm2d(64),
                                 nn.MaxPool2d(2,2),
                                 
                                 nn.Conv2d(64,128,3,1,1),
                                 nn.ReLU(inplace = True),
                                 nn.BatchNorm2d(128),
                                 nn.Conv2d(128,256,3,1,1),
                                 nn.ReLU(inplace = True),
                                 nn.BatchNorm2d(256),
                                 nn.MaxPool2d(2,2),
                                 nn.Dropout2d(p=0.3),
                                 
                                 nn.Conv2d(256,512,3,1,1),
                                 nn.ReLU(inplace = True),
                                 nn.BatchNorm2d(512),
                                 nn.Conv2d(512,512,3,1,1),
                                 nn.ReLU(inplace = True),
                                 nn.BatchNorm2d(512),
                                 nn.MaxPool2d(2,2)
                                )
        
        # Defining Classifier
        # Classifier Architecture:
        '''
        CNN->Flatten->
        Linear->ReLU->
        Linear->ReLU->Dropout->
        Linear->ReLU->
        Linear-> Scores
        '''
        self.classifier = nn.Sequential(nn.Linear(8192,2048),
                                        nn.ReLU(inplace=True),
                                        
                                        nn.Linear(2048,1024),
                                        nn.ReLU(inplace=True),
                                        nn.Dropout(p=0.3),
                                        
                                        nn.Linear(1024,512),
                                        nn.ReLU(inplace=True),
                                        
                                        nn.Linear(512,10)
                                       )
        
    def forward(self,x):
        
        # Forward Propagation 
        x = self.cnn(x)
        x = x.view(-1,4*4*512)
        x = self.classifier(x)
        
        return x

# %% [markdown]
# **GPU!**

# %%
print("GPU Available:",torch.cuda.is_available())
print("Number of GPU available:",torch.cuda.device_count())
# Out:
# GPU Available: True
# Number of GPU available: 1

# %%
device = torch.device("cpu")
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("Running on the GPU")
else:
    print("Running on the CPU")
# Out:
# Running on the GPU

# %% [markdown]
# **DEFINING NET, LOSS AND OPTIMIZER**

# %%
net = CNN()
net.to(device)
loss_func = nn.CrossEntropyLoss()
opt = optim.Adam(params = net.parameters(), lr=1e-3)

# %% [markdown]
# **TRAINING and VIZUALISATION of MODEL**

# %%
num_epoch = 20
a,b,c = train(net,loss_func,opt,num_epoch)
# Out:
# Epoch 1/20
# Iteration: 50, loss = 1.66
# Iteration: 100, loss = 1.64
# Iteration: 150, loss = 1.42
# Iteration: 200, loss = 1.17
# Iteration: 250, loss = 1.32
# Iteration: 300, loss = 1.17
# Iteration: 350, loss = 1.13
# Checking accuracy on validation set
# Got 639 / 1000 correct (63.90)
# Epoch 2/20
# Iteration: 400, loss = 0.99
# Iteration: 450, loss = 1.21
# Iteration: 500, loss = 0.96
# Iteration: 550, loss = 0.92
# Iteration: 600, loss = 0.93
# Iteration: 650, loss = 0.70
# Iteration: 700, loss = 0.91
# Iteration: 750, loss = 0.77
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
# Epoch 3/20
# Iteration: 800, loss = 0.74
# Iteration: 850, loss = 0.67
# Iteration: 900, loss = 0.59
# Iteration: 950, loss = 0.94
# Iteration: 1000, loss = 0.59
# Iteration: 1050, loss = 0.59
# Iteration: 1100, loss = 0.52
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
# Epoch 4/20
# Iteration: 1150, loss = 0.49
# Iteration: 1200, loss = 0.74
# Iteration: 1250, loss = 0.50
# Iteration: 1300, loss = 0.51
# Iteration: 1350, loss = 0.61
# Iteration: 1400, loss = 0.61
# Iteration: 1450, loss = 0.50
# Iteration: 1500, loss = 0.75
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
# Epoch 5/20
# Iteration: 1550, loss = 0.37
# Iteration: 1600, loss = 0.46
# Iteration: 1650, loss = 0.31
# Iteration: 1700, loss = 0.50
# Iteration: 1750, loss = 0.45
# Iteration: 1800, loss = 0.55
# Iteration: 1850, loss = 0.53
# Iteration: 1900, loss = 0.46
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
# Epoch 6/20
# Iteration: 1950, loss = 0.32
# Iteration: 2000, loss = 0.34
# Iteration: 2050, loss = 0.47
# Iteration: 2100, loss = 0.34
# Iteration: 2150, loss = 0.24
# Iteration: 2200, loss = 0.27
# Iteration: 2250, loss = 0.22
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
# Epoch 7/20
# Iteration: 2300, loss = 0.24
# Iteration: 2350, loss = 0.26
# Iteration: 2400, loss = 0.22
# Iteration: 2450, loss = 0.22
# Iteration: 2500, loss = 0.20
# Iteration: 2550, loss = 0.30
# Iteration: 2600, loss = 0.12
# Iteration: 2650, loss = 0.21
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
# Epoch 8/20
# Iteration: 2700, loss = 0.11
# Iteration: 2750, loss = 0.21
# Iteration: 2800, loss = 0.17
# Iteration: 2850, loss = 0.22
# Iteration: 2900, loss = 0.10
# Iteration: 2950, loss = 0.18
# Iteration: 3000, loss = 0.09
# Iteration: 3050, loss = 0.13
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
# Epoch 9/20
# Iteration: 3100, loss = 0.24
# Iteration: 3150, loss = 0.12
# Iteration: 3200, loss = 0.17
# Iteration: 3250, loss = 0.11
# Iteration: 3300, loss = 0.11
# Iteration: 3350, loss = 0.11
# Iteration: 3400, loss = 0.21
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
# Epoch 10/20
# Iteration: 3450, loss = 0.11
# Iteration: 3500, loss = 0.05
# Iteration: 3550, loss = 0.06
# Iteration: 3600, loss = 0.09
# Iteration: 3650, loss = 0.13
# Iteration: 3700, loss = 0.08
# Iteration: 3750, loss = 0.05
# Iteration: 3800, loss = 0.06
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
# Epoch 11/20
# Iteration: 3850, loss = 0.05
# Iteration: 3900, loss = 0.08
# Iteration: 3950, loss = 0.03
# Iteration: 4000, loss = 0.20
# Iteration: 4050, loss = 0.09
# Iteration: 4100, loss = 0.11
# Iteration: 4150, loss = 0.13
# Iteration: 4200, loss = 0.06
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
# Epoch 12/20
# Iteration: 4250, loss = 0.20
# Iteration: 4300, loss = 0.12
# Iteration: 4350, loss = 0.09
# Iteration: 4400, loss = 0.11
# Iteration: 4450, loss = 0.06
# Iteration: 4500, loss = 0.02
# Iteration: 4550, loss = 0.11
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
# Epoch 13/20
# Iteration: 4600, loss = 0.04
# Iteration: 4650, loss = 0.10
# Iteration: 4700, loss = 0.11
# Iteration: 4750, loss = 0.06
# Iteration: 4800, loss = 0.03
# Iteration: 4850, loss = 0.11
# Iteration: 4900, loss = 0.05
# Iteration: 4950, loss = 0.09
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
# Epoch 14/20
# Iteration: 5000, loss = 0.03
# Iteration: 5050, loss = 0.09
# Iteration: 5100, loss = 0.09
# Iteration: 5150, loss = 0.01
# Iteration: 5200, loss = 0.02
# Iteration: 5250, loss = 0.07
# Iteration: 5300, loss = 0.07
# Iteration: 5350, loss = 0.02
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
# Epoch 15/20
# Iteration: 5400, loss = 0.05
# Iteration: 5450, loss = 0.06
# Iteration: 5500, loss = 0.03
# Iteration: 5550, loss = 0.05
# Iteration: 5600, loss = 0.04
# Iteration: 5650, loss = 0.04
# Iteration: 5700, loss = 0.15
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
# Epoch 16/20
# Iteration: 5750, loss = 0.07
# Iteration: 5800, loss = 0.02
# Iteration: 5850, loss = 0.08
# Iteration: 5900, loss = 0.10
# Iteration: 5950, loss = 0.04
# Iteration: 6000, loss = 0.09
# Iteration: 6050, loss = 0.01
# Iteration: 6100, loss = 0.03
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
# Epoch 17/20
# Iteration: 6150, loss = 0.01
# Iteration: 6200, loss = 0.02
# Iteration: 6250, loss = 0.16
# Iteration: 6300, loss = 0.02
# Iteration: 6350, loss = 0.07
# Iteration: 6400, loss = 0.04
# Iteration: 6450, loss = 0.03
# Iteration: 6500, loss = 0.04
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
# Epoch 18/20
# Iteration: 6550, loss = 0.05
# Iteration: 6600, loss = 0.01
# Iteration: 6650, loss = 0.06
# Iteration: 6700, loss = 0.17
# Iteration: 6750, loss = 0.04
# Iteration: 6800, loss = 0.13
# Iteration: 6850, loss = 0.10
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
# Epoch 19/20
# Iteration: 6900, loss = 0.02
# Iteration: 6950, loss = 0.22
# Iteration: 7000, loss = 0.02
# Iteration: 7050, loss = 0.02
# Iteration: 7100, loss = 0.04
# Iteration: 7150, loss = 0.11
# Iteration: 7200, loss = 0.04
# Iteration: 7250, loss = 0.01
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
# Epoch 20/20
# Iteration: 7300, loss = 0.02
# Iteration: 7350, loss = 0.00
# Iteration: 7400, loss = 0.03
# Iteration: 7450, loss = 0.01
# Iteration: 7500, loss = 0.03
# Iteration: 7550, loss = 0.13
# Iteration: 7600, loss = 0.02
# Iteration: 7650, loss = 0.01
# Checking accuracy on validation set
# Got 854 / 1000 correct (85.40)

# %%
vizualize(a,b,c,num_epoch)

# %%
_ = check_accuracy(net,testLoader)
# Out:
# Checking accuracy on test set
# Got 8336 / 10000 correct (83.36)

# %% [markdown]
# **SAVING MODEL**

# %%
print("Model's state_dict:")
for param_tensor in net.state_dict():
    print(param_tensor, "\t", net.state_dict()[param_tensor].size())
'''
# Print optimizer's state_dict
print("Optimizer's state_dict:")
for var_name in opt.state_dict():
    print(var_name, "\t", opt.state_dict()[var_name])
'''
# Out:
# Model's state_dict:
# cnn.0.weight 	 torch.Size([32, 3, 3, 3])
# cnn.0.bias 	 torch.Size([32])
# cnn.2.weight 	 torch.Size([32])
# cnn.2.bias 	 torch.Size([32])
# cnn.2.running_mean 	 torch.Size([32])
# cnn.2.running_var 	 torch.Size([32])
# cnn.2.num_batches_tracked 	 torch.Size([])
# cnn.3.weight 	 torch.Size([64, 32, 3, 3])
# cnn.3.bias 	 torch.Size([64])
# cnn.5.weight 	 torch.Size([64])
# cnn.5.bias 	 torch.Size([64])
# cnn.5.running_mean 	 torch.Size([64])
# cnn.5.running_var 	 torch.Size([64])
# cnn.5.num_batches_tracked 	 torch.Size([])
# cnn.7.weight 	 torch.Size([128, 64, 3, 3])
# cnn.7.bias 	 torch.Size([128])
# cnn.9.weight 	 torch.Size([128])
# cnn.9.bias 	 torch.Size([128])
# cnn.9.running_mean 	 torch.Size([128])
# cnn.9.running_var 	 torch.Size([128])
# cnn.9.num_batches_tracked 	 torch.Size([])
# cnn.10.weight 	 torch.Size([256, 128, 3, 3])
# cnn.10.bias 	 torch.Size([256])
# cnn.12.weight 	 torch.Size([256])
# cnn.12.bias 	 torch.Size([256])
# cnn.12.running_mean 	 torch.Size([256])
# cnn.12.running_var 	 torch.Size([256])
# cnn.12.num_batches_tracked 	 torch.Size([])
# cnn.15.weight 	 torch.Size([512, 256, 3, 3])
# cnn.15.bias 	 torch.Size([512])
# cnn.17.weight 	 torch.Size([512])
# cnn.17.bias 	 torch.Size([512])
# cnn.17.running_mean 	 torch.Size([512])
# cnn.17.running_var 	 torch.Size([512])
# cnn.17.num_batches_tracked 	 torch.Size([])
# cnn.18.weight 	 torch.Size([512, 512, 3, 3])
# cnn.18.bias 	 torch.Size([512])
# cnn.20.weight 	 torch.Size([512])
# cnn.20.bias 	 torch.Size([512])
# cnn.20.running_mean 	 torch.Size([512])
# cnn.20.running_var 	 torch.Size([512])
# cnn.20.num_batches_tracked 	 torch.Size([])
# classifier.0.weight 	 torch.Size([2048, 8192])
# classifier.0.bias 	 torch.Size([2048])
# classifier.2.weight 	 torch.Size([1024, 2048])
# classifier.2.bias 	 torch.Size([1024])
# classifier.5.weight 	 torch.Size([512, 1024])
# classifier.5.bias 	 torch.Size([512])
# classifier.7.weight 	 torch.Size([10, 512])
# classifier.7.bias 	 torch.Size([10])
# '\n# Print optimizer\'s state_dict\nprint("Optimizer\'s state_dict:")\nfor var_name in opt.state_dict():\n    print(var_name, "\t", opt.state_dict()[var_name])\n'

# %%
torch.save(net.state_dict(), 'cnn_model_cifar10_state_dict.pth')
torch.save(net, 'cnn_model_cifar10.pth')
# Out:
# C:\Users\tashv\anaconda3\lib\site-packages\torch\serialization.py:402: UserWarning: Couldn't retrieve source code for container of type CNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# **LOADING MODEL**

# %% [raw]
# *******************************************
# model = CNN(*args, **kwargs)              *
# model.load_state_dict(torch.load(PATH))   *
# *******************************************
# model = torch.load(PATH)                  *
# *******************************************
